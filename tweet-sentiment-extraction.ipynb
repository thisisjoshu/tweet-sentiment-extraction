# %%
import numpy as np
import pandas as pd
import string
import re
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

pd.options.mode.chained_assignment = None

# %%
dir_name = 'datasets/'
df_tr = pd.read_csv(dir_name + 'train.csv')
df_te = pd.read_csv(dir_name + 'test.csv')

# Remove empty rows from training dataset
df_tr = df_tr[df_tr['text'].notna()]

# %%
# explore the data and render images for report

# %%
def jaccard(str1, str2):
    a = set(str1.lower().split()) 
    b = set(str2.lower().split())
    c = a.intersection(b)
    score = float(len(c)) / ((len(a) + len(b)) - len(c))
    
    return score

def text_preprocess(text):
    text = text.lower()
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('\w*\d\w*', '', text) 
    text = re.sub('https?://\S+|www\.\S+', '', text)
    
    return text

def proportion_calculation(dataset, f_mat):
    dictt = {}
    df = pd.DataFrame(f_mat.toarray(), columns=vectorizer.get_feature_names())
    
    for i in vectorizer.get_feature_names():
        summ = df[i].sum()
        dictt[i] = summ / len(dataset)
     
    return dictt

def weight_calculation(target, cat_1, cat_2):
    adjusted_weight = {}
    
    for key, value in target.items():
        adjusted_weight[key] = target[key] - (cat_1[key] + cat_2[key])
        
    return adjusted_weight

def create_subsets(words):
    return [words[i:j + 1] for i in range(len(words)) for j in range(i, len(words))]

def predict_selected_text(tweet_data, dictionary, tolerance):
    text = tweet_data['text']
    sentiment = tweet_data['sentiment']
    
    # if sentiment is neutral or text is less than 3 words then return whole text
    if(sentiment == 'neutral'):
        return text
    elif(len(text) < 3):
        return text
    
    word_dict = dictionary[sentiment][sentiment]
    
    selected_text = str()
    words = text.split()
    subsets = create_subsets(words)
    sorted_list = sorted(subsets, key=len)
    
    score = 0
    for i in range(len(subsets)):
        n_sum = 0
        for j in range(len(sorted_list[i])):
            if(sorted_list[i][j] in word_dict.keys()):
                n_sum += word_dict[sorted_list[i][j]]
                      
        if(n_sum > score + tolerance):
            score = n_sum
            selected_text = sorted_list[i]
                
    if(len(selected_text) == 0):
        selected_text = words
                
            
    return ' '.join(selected_text)

# calculate score for validation set
def validation(dataset, dictionaries):
    tolerance = 0.001
    
    dataset['predicted'] = str()

    for index, row in dataset.iterrows():
        predicted = predict_selected_text(row, dictionaries, tolerance)
        dataset.loc[dataset['textID'] == row['textID'],['predicted']] = predicted
        
    dataset['jaccard'] = dataset.apply(lambda x: jaccard(x.selected_text, x.predicted), axis = 1)
    print('jaccard score is: {}'.format(np.mean(dataset['jaccard'])))

# %%
# simple preprocessing
df_tr['text'] = df_tr['text'].apply(lambda x: text_preprocess(x))
df_tr['selected_text'] = df_tr['selected_text'].apply(lambda x: text_preprocess(x))
df_te['text'] = df_te['text'].apply(lambda x: text_preprocess(x))

# split training data
X_train, X_test = train_test_split(df_tr, test_size = 0.2, random_state = 0)

train_pos = X_train[X_train['sentiment'] == 'positive']
train_neu = X_train[X_train['sentiment'] == 'neutral']
train_neg = X_train[X_train['sentiment'] == 'negative']


all_pos = str()
all_neg = str()
all_neu = str()
for i in train_pos['text']:
    all_pos += i

for i in train_neg['text']:
    all_neg += i

for i in train_neu['text']:
    all_neu += i
    
data = [all_pos, all_neg, all_neu]

vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, max_features=50000, stop_words='english')
r = vectorizer.fit_transform(data)


features = vectorizer.get_feature_names()
index = [n for n in data]
df = pd.DataFrame(r.T.todense(), index=features, columns=index)

#print(df.rename(columns={'A': 'a', 'C': 'c'}))

new_df = df.rename(columns={all_pos: 'positive', all_neg: 'negative', all_neu: 'neutral'})
#new_df.head(n=30)

pos_df = new_df.filter(regex='pos')
neg_df = new_df.filter(regex='neg')
neu_df = new_df.filter(regex='neu')

pos_dict = pos_df.to_dict()
neg_dict = neg_df.to_dict()
neu_dict = neu_df.to_dict()

weight_dictionary = { 'positive': pos_dict, 'negative': neg_dict, 'neutral': neu_dict}
#print(weight_dictionary['positive']['positive'])
validation(X_test, weight_dictionary)
#pos_df.head()
#print(df[all_pos])
# Out:
# jaccard score is: 0.5809001834813189

# %%
X_test.head(n=30)
# Out:
#            textID                                               text  \
# 20673  3391184efc                  loves the nice weather and  exams
# 12581  b35daf9677  okay this weather isnt cute sundress friendly ...
# 13136  06e5249859                            woo hoo congratulations
# 14013  3cd4960670   thanks   got a hold of someone there who knew...
# 25030  92b75314ca  got back and putting in the laundry we got in ...
# 19380  7438c9c09a                     congrats on graduating college
# 17226  fa042d9ad5  can you get me a sub from subway when ur on yo...
# 10078  a4ede54987  its the weekend but  year old is grounded whic...
# 3440   35124a7481   its been fine for me for like a week but now ...
# 6294   e4b6c9a295                       ntah i really wanna be there
# 7434   e2e0d8b057  i have class tomorrow and tomorrow is saturday...
# 12923  42bcc63043  going to bed busy day tomorrowhappy mothers da...
# 18646  e22c5b9096  watering the plants at home drinking a delicio...
# 12033  756a6abdba   loved your blog from the musicares event good...
# 20150  8e39e8f318  lunch is boringgg  driving after school today ...
# 4128   93de1656ca   omg i dont blame you hope you didnt hurt him ...
# 21313  4b53d107bd  zzzz im taking my mom out for breakfast tomorr...
# 20986  f977627ef9                first night sleeping in my new home
# 5486   a1fb351142      naw forget it then i will only if u take them
# 15701  ab447d7be6              kakabalik lang from tarlac good aftie
# 11512  b3ce954b4a   those were the good days the jetsons comes on...
# 10395  177c67cad4  theres nothing worse than getting a text about...
# 6009   e9f57bf9da                                   youre telling me
# 8604   9992b5a34d  sigh im going to bed i just dont feel right an...
# 1091   57558f3cbe  just wanted to say positivity is doin me good ...
# 22070  3e56c631c0  gotta go bye twitterland  good night ill try s...
# 21062  adca191e66                        loves finding new followers
# 10993  3b23a9ea15            well i still cant wait for the one shot
# 9155   5db904a131   i like it too  i hadnt seen the clip before t...
# 15741  cb2279233d   youve got the  tsk tsk tsk its a shame  haha ...
#
#                                            selected_text sentiment  \
# 20673                                              loves  positive
# 12581  okay this weather isnt cute sundress friendly ...   neutral
# 13136                                    congratulations  positive
# 14013                                             thanks  positive
# 25030  got back and putting in the laundry we got in ...   neutral
# 19380                                           congrats  positive
# 17226  can you get me a sub from subway when ur on yo...   neutral
# 10078  its the weekend but  year old is grounded whic...   neutral
# 3440   its been fine for me for like a week but now i...   neutral
# 6294                                               wanna  positive
# 7434                                                hate  negative
# 12923                                  happy mothers day  positive
# 18646                                          delicious  positive
# 12033                                          good work  positive
# 20150                                  lunch is boringgg  negative
# 4128                                                hope  positive
# 21313                             shall be quite a treat  positive
# 20986                first night sleeping in my new home   neutral
# 5486       naw forget it then i will only if u take them   neutral
# 15701                                               good  positive
# 11512  those were the good days the jetsons comes on ...   neutral
# 10395                                      nothing worse  negative
# 6009                                    youre telling me   neutral
# 8604                      i just dont feel right anymore  negative
# 1091   positivity is doin me good change it up wont r...  positive
# 22070  gotta go bye twitterland  good night ill try s...   neutral
# 21062                                              loves  positive
# 10993            well i still cant wait for the one shot   neutral
# 9155                                         pretty cool  positive
# 15741                                           l better  positive
#
#                                                predicted   jaccard
# 20673                   loves the nice weather and exams  0.166667
# 12581  okay this weather isnt cute sundress friendly ...  1.000000
# 13136                            woo hoo congratulations  0.333333
# 14013  thanks got a hold of someone there who knew th...  0.083333
# 25030  got back and putting in the laundry we got in ...  1.000000
# 19380                                         graduating  0.000000
# 17226  can you get me a sub from subway when ur on yo...  1.000000
# 10078  its the weekend but  year old is grounded whic...  1.000000
# 3440    its been fine for me for like a week but now ...  1.000000
# 6294                        ntah i really wanna be there  0.166667
# 7434   i have class tomorrow and tomorrow is saturday...  0.111111
# 12923                                                 te  0.000000
# 18646                                           smoothie  0.000000
# 12033  loved your blog from the musicares event good ...  0.222222
# 20150  lunch is boringgg driving after school today u...  0.200000
# 4128   omg i dont blame you hope you didnt hurt him t...  0.090909
# 21313  zzzz im taking my mom out for breakfast tomorr...  0.357143
# 20986                first night sleeping in my new home  1.000000
# 5486       naw forget it then i will only if u take them  1.000000
# 15701              kakabalik lang from tarlac good aftie  0.166667
# 11512   those were the good days the jetsons comes on...  1.000000
# 10395  worse than getting a text about a dog that was...  0.090909
# 6009                                    youre telling me  1.000000
# 8604   sigh im going to bed i just dont feel right an...  0.545455
# 1091                                             forsure  0.090909
# 22070  gotta go bye twitterland  good night ill try s...  1.000000
# 21062                        loves finding new followers  0.250000
# 10993            well i still cant wait for the one shot  1.000000
# 9155   i like it too i hadnt seen the clip before tho...  0.166667
# 15741  youve got the tsk tsk tsk its a shame haha fee...  0.083333
